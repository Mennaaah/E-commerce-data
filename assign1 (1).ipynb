# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
file='F:\\2019\\fall\\data analytics\\assignemt 1.csv'
df=pd.read_csv(file)

# %%
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0     835 Frank Tunnel\r\nWrightmouth, MI 82180-9605            Violet
# 1   4547 Archer Common\r\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\r\nCobbborough,...            Bisque
# 3  1414 David Throughway\r\nPort Jason, OH 22070-...       SaddleBrown
# 4  14023 Rodriguez Passage\r\nPort Jacobville, PR...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
#df['Length of Membership'][5]
# Out:
# nan

# %%
#df['Length of Membership'][:] = df['Length of Membership'].replace(0, np.NaN)

# %%
#replacing the the nan values with zeros
col1=df['Length of Membership'].fillna(0)

# %%
corr_zeros=col1.corr(df['Yearly Amount Spent'])
print("The corrleation between the 2 coloums after 1st approach is ",corr_zeros )
# Out:
# The corrleation between the 2 coloums after 1st approach is  0.49984210923817307

# %%
#file='F:\\2019\\fall\\data analytics\\assignemt 1.csv'
#df=pd.read_csv(file)
#colum2=df['Length of Membership']

# %%
#replacing the nan values with the mean in a new variables called colum 2
colum2=df['Length of Membership'].fillna(df['Length of Membership'].mean())
corr_mean=colum2.corr(df['Yearly Amount Spent'])
print("The corrleation between the 2 coloums after 2nd approach is ",corr_mean )
# Out:
# The corrleation between the 2 coloums after 2nd approach is  0.7711501323326936

# %%
#replacing the nan values with the median in a new variables called colum 3
colum3=df['Length of Membership'].fillna(df['Length of Membership'].median())
corr_med=colum3.corr(df['Yearly Amount Spent'])
print("The corrleation between the 2 coloums after 3nd approach is ",corr_med )
# Out:
# The corrleation between the 2 coloums after 3nd approach is  0.7711298744904648

# %%
import time
time_start=time.perf_counter()
mediandf=df['Length of Membership'].median()
time_end=time.perf_counter()
t_diff_median=time_end-time_start
time_start_mean=time.perf_counter()
meandf=df['Length of Membership'].mean()
time_end_mean=time.perf_counter()
t_diff_mean=time_end_mean-time_start_mean
print("the time needed for calculation of mean is",t_diff_mean )
print("the time needed for calculation of median is",t_diff_median )
t_diff_mean<t_diff_median
# Out:
# the time needed for calculation of mean is 9.80000477284193e-05
# the time needed for calculation of median is 0.00018880004063248634
# True

# %% [raw]
# The first approach is very biased as it ignores the real values and put it as zeros which means that the users has zero time of length of membership which is not the case, as the coloums before it shows that the users already have time on the app, and even if these coulums did not show this, the probablity of a user who has zero lenght of membership will be only the time before regiseteration which is not the case also.
# The second and third approach are better in my point of view, as they replace the missing data with numbers are expected to be the case. Also, the median is better than mean in case of there's alot of outlier which is not the case here I clculated the upper and lower limits in the excel file to get the upper limit=5.939289309, and the lower limit=1.106061751, which in comparison to the values in the coloum shows that there are very few outlier. So, there's no need to spend more time in calculating the median(the median calculation takes more time than mean calculation as shown in the previous cell) while we can calculate the mean when we have very few outliers.
# I would recommend the second approach as it it more logical alternative, as zeros values decrease it so much, and the second approach alse makes sense
# because the more the user use the website, the more he//she spend money yearly, which means the higher the correlation factor

# %%
#I would recommend the second approach as it it more logical alternative, as zeros values decrease it so much, and the second approach alse makes sense
#because the more the user use the website, the more he//she spend money yearly, which means the higher the correlation factor

# %%
from sklearn.preprocessing import StandardScaler
#we can't do normalization when we have missing values, so i will use the replaced missing values of means
df['Length of Membership']=df['Length of Membership'].fillna(df['Length of Membership'].mean())

#getting the whole features in one varibles to know which is more effective, but of course e-mails,address, avatar have
#nothing to do with the yearly spent amount so, we won't take it into calculations
x=df.iloc[:, 3:-1].values
y=df.iloc[:, -1].values
# normalizing the features before pca
x = StandardScaler().fit_transform(x)

# %%
# Out:
# 1.0

# %%
from sklearn.decomposition import PCA
pca= PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalComponents
# Out:
# array([[-1.37672290e+00,  1.54547499e+00],
#        [-6.10910460e-02, -1.62396022e+00],
#        [ 4.30627372e-01,  1.78992838e-01],
#        [-3.22610199e-01,  9.09740298e-01],
#        [-6.13291791e-01,  1.17771154e+00],
#        [ 2.03901048e+00,  2.95407381e-01],
#        [ 2.41854137e-01, -8.07999449e-01],
#        [-4.78034496e-01,  6.89265301e-01],
#        [-7.67912789e-01,  7.86766109e-01],
#        [-3.93089705e-01, -9.34466669e-01],
#        [-5.76496476e-01,  1.17144056e-01],
#        [ 6.35489232e-01,  4.14741946e-01],
#        [-1.00519852e+00, -1.80971447e+00],
#        [ 8.04990855e-02,  3.54487820e-01],
#        [-7.40007501e-01, -8.14853682e-01],
#        [-8.05385910e-01, -1.18804991e+00],
#        [ 1.19549780e+00, -1.02733268e+00],
#        [-1.19432138e+00, -1.22396620e+00],
#        [-2.91801621e+00, -1.06818687e+00],
#        [-1.46276177e+00,  9.07621908e-01],
#        [ 7.39606816e-02,  5.70472782e-01],
#        [-6.79812399e-01, -1.04342391e+00],
# ...

# %%
#crating df with the new 2 features

principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
principalDf.head()
# Out:
#    principal component 1  principal component 2
# 0              -1.376723               1.545475
# 1              -0.061091              -1.623960
# 2               0.430627               0.178993
# 3              -0.322610               0.909740
# 4              -0.613292               1.177712
